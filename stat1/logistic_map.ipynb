# %%
import numpy as np
import matplotlib.pyplot as plt

def f(gens=20, init=0.1, r=4):
    x = [init]
    for i in range(gens-1):
        xn = x[i]
        x.append(r* xn * (1 - xn))
    return x

# %%
plt.plot(f(30,0.1,4))
plt.plot(f(30,0.1000001,4))
